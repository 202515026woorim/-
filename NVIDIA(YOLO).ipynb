# %% [markdown]
# <a href="https://colab.research.google.com/github/202515026woorim/-/blob/main/NVIDIA(YOLO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# YOLOv8 모델 로드 (사전 훈련된 모델)
model = YOLO('yolov8n.pt')  # 'n'은 nano 버전, 필요에 따라 's', 'm', 'l', 'x' 변경 가능

# %%
results = model('1.jpg', save=True)
# Out:
# image 1/1 /content/1.jpg: 448x640 10 persons, 1 bus, 2 ties, 406.7ms
# Speed: 9.9ms preprocess, 406.7ms inference, 36.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
# !wget -O 1.jpg https://ultralytics.com/images/zidane.jpgresults = model('image.jpg', save=True)
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `wget -O 1.jpg https://ultralytics.com/images/zidane.jpgresults = model('image.jpg', save=True)'

# %%
from ultralytics import YOLO

# YOLOv8 모델 로드
model = YOLO('yolov8n.pt')  # 필요한 모델 크기에 맞게 변경 가능 (yolov8s.pt, yolov8m.pt 등)

# 이미지에서 객체 탐지 수행
results = model('/content/1.jpg', save=True)
# Out:
# image 1/1 /content/1.jpg: 448x640 10 persons, 1 bus, 2 ties, 232.9ms
# Speed: 12.2ms preprocess, 232.9ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2

# %%
from IPython.display import display
from PIL import Image

# 결과 이미지 파일 경로 (결과 폴더에 저장된 첫 번째 이미지)
result_img_path = '/content/runs/detect/predict/1.jpg'

# 이미지 표시
display(Image.open(result_img_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>
